# %% [markdown]
# # Final Project: Part 1 - Planning & Exploration
#
# The final project for this course does not need to be complicated. Keep it simple, fun and interesting!!
# This notebook will guide you through the planning and exploration phase of your final project. Your goal is to come up with a simple prototype idea and explore which Python tools, libraries, and data formats could be useful for building it, using the concepts we are learning in CS114.
# You’ll also practice some light coding to test out potential components — such as reading data, using a standard library, or trying a third-party package.
#
# ---
#
# ## 🎯 Learning Objectives
#
# - Brainstorm and outline a Python project idea related to your interests.
#
# - Identify which Python standard libraries might be useful.
#
# - Choose and briefly explore at least one third-party library (e.g. pandas, geopandas, matplotlib, requests, scikit-learn, pygame, astropy, etc.).
#
# - Understand how to import, test, and use libraries for data handling and/or visualization.
# ---

# %% [markdown]
# ## 1. Project Idea Exploration
#
# **Question 1.1:** Describe your project idea in 3–5 sentences.
#
# What topic interests you?
#
# What is your project trying to show, analyze, or automate?

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 1.2:** What will be the inputs and outputs of your project?
#
# Examples:
# - My project will take a CSV file of air quality data and visualize levels over time.
# - My project will be a game that interacts with a user and gives them a score.
# - My project will take in an image and provide the user with what the image represents.

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# ## 2. Standard Library Exploration
#
# **Question 2.1:** List at least two Python standard libraries you plan to use and explain why.
# (Example: collections for creating a Counter data structure, random for simulation, re for regular expressions in files/strings, urllib to open/read urls).
#
# Explore by looking at the documentation on [Python's standard libraries](https://docs.python.org/3/library/)

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 2.2:** Try importing and using them in a short code cell.

# %%
# TODO: import the libraries you mention above and use the in a brief example

# %% [markdown]
# ## 3. File Formats and Data
#
# **Question 3.1**: What type of data, file formats or interface might your project involve?
# (e.g., CSV, JSON, text files, API data, etc.)

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 3.2:** Try loading or creating a small sample dataset that you might use later.

# %%
# TODO: add code here

# %% [markdown]
# ## 4. Third-Party Library Exploration
#
# **Question 4.1:** Identify one third-party library you would like to explore for your project (e.g., matplotlib, pandas, scikit-learn). Discuss with your instructor or tutor, if you need guidance.

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 4.2:** Try a simple example using it.

# %%
# TODO: add a simple code example here

# %% [markdown]
# ## 5. Incorporating concepts from CS114
#
# **Question 5.1:** How do you plan on applying the following concepts in your project? Briefly describe how the concepts will be incorporated in your project.
# - Use of functions and OOP
# - Use of some Pythonic techniques such as list comprehension and/or functional programming techniques
# - Includes some unit testing (either simple asserts or using the unittest module)
# - Read and/or write data from files
# - Any other concepts that you would like to include

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 5.2:** Write a short code snippet that could be part of your project later — for example, a function to calculate something or clean data.

# %%
# TODO: add code here

# %% [markdown]
# ## 6. Reflection & Discussion
# **Question 1.1:** Write a short paragraph that answers the following:
# - What challenges do you anticipate with this project?
# - What do you need to learn or review to move forward?
# - What would success look like for your prototype?

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# **Question 1.2:** Discuss your project idea and reflection with a peer. See if they can provide you with suggestions.
# In the markdown cell below, provide the name of your discussion partner as well as a brief summary with at least one suggestion. Once you are done, get signed off by your instructor or tutor during lab or tutoring hours.

# %% [markdown]
# *Replace this text with your answer*

# %% [markdown]
# ### Congratulations!
# You’ve finished part 1 of the final project and are ready to start part 2 - design & development.
